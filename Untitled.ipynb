# %%
import pandas as pd

# Create DataFrame
data = {
    'Product': ['A', 'B', 'A', 'C', 'B', 'A', 'C', 'B'],
    'Region': ['East', 'West', 'East', 'North', 'West', 'South', 'North', 'East']
}

df = pd.DataFrame(data)

print(df)
# Out:
#   Product Region
# 0       A   East
# 1       B   West
# 2       A   East
# 3       C  North
# 4       B   West
# 5       A  South
# 6       C  North
# 7       B   East

# %%
df.shape
# Out:
# (8, 2)

# %%
df.size
# Out:
# 16

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Product  8 non-null      object
#  1   Region   8 non-null      object
# dtypes: object(2)
# memory usage: 260.0+ bytes

# %%
df.describe()
# Out:
#        Product Region
# count        8      8
# unique       3      4
# top          A   East
# freq         3      3
