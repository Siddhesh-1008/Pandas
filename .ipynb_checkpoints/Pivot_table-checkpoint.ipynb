# %%
# GROUP BY AND PIVOT TABLES ARE SIMILAR

# %%
# groupby()

# 👉 Output hierarchical/index style me deta hai.

# pivot_table()

# 👉 Proper table format me deta hai.

# %%
import pandas as pd
import numpy as np

# Create DataFrame
data = {
    'Date': pd.date_range('2023-01-01', periods=20),
    'Product': ['A', 'B', 'C', 'D'] * 5,
    'Region': ['East', 'West', 'North', 'South'] * 5,
    'Sales': np.random.randint(100, 1000, 20),
    'Units': np.random.randint(10, 100, 20),
    'Rep': ['John', 'Mary', 'Bob', 'Alice'] * 5
}

df = pd.DataFrame(data)

# Add Month Column
df['Month'] = df['Date'].dt.month_name()

# Add Quarter Column
df['Quarter'] = 'Q' + df['Date'].dt.quarter.astype(str)

print(df)
# Out:
#          Date Product Region  Sales  Units    Rep    Month Quarter
# 0  2023-01-01       A   East    356     72   John  January      Q1
# 1  2023-01-02       B   West    914     13   Mary  January      Q1
# 2  2023-01-03       C  North    578     89    Bob  January      Q1
# 3  2023-01-04       D  South    631     82  Alice  January      Q1
# 4  2023-01-05       A   East    407     60   John  January      Q1
# 5  2023-01-06       B   West    476     25   Mary  January      Q1
# 6  2023-01-07       C  North    236     84    Bob  January      Q1
# 7  2023-01-08       D  South    829     14  Alice  January      Q1
# 8  2023-01-09       A   East    265     48   John  January      Q1
# 9  2023-01-10       B   West    921     43   Mary  January      Q1
# 10 2023-01-11       C  North    651     19    Bob  January      Q1
# 11 2023-01-12       D  South    121     75  Alice  January      Q1
# 12 2023-01-13       A   East    118     94   John  January      Q1
# 13 2023-01-14       B   West    776     96   Mary  January      Q1
# 14 2023-01-15       C  North    618     51    Bob  January      Q1
# 15 2023-01-16       D  South    582     19  Alice  January      Q1
# 16 2023-01-17       A   East    684     73   John  January      Q1
# 17 2023-01-18       B   West    889     65   Mary  January      Q1
# 18 2023-01-19       C  North    238     31    Bob  January      Q1
# 19 2023-01-20       D  South    447     70  Alice  January      Q1
